# %%
using ITensors
using ITensorMPS
using LinearAlgebra
using PolyChaos
using QuadGK
using Plots
using Strided

BLAS.set_num_threads(8)
Strided.disable_threads()
ITensors.enable_threaded_blocksparse(false)
# Out:
# false

# %%
function spectral_func(input::AbstractString, D::Float64, g::Float64)
    inband = x -> (-D <= x <= D)
        
    if input == "flat"
        J = x -> inband(x) ? 1/(2D) : 0.0
    elseif input == "elliptical"
        J = x -> inband(x) ? sqrt(1 - (x/D)^2) : 0.0
    elseif input == "ohmic"
        J = x -> inband(x) ? abs(x) : 0.0
    elseif input == "lorentzian"
        J = x -> 1/(1 + (x/D)^2)
    else
        error("spectral function type not recognized")
    end
    # normalization
    norm = quadgk(J, -D, D)[1]           
    Jnorm = x -> g*D/pi * J(x) / norm
    return Jnorm
end

function thermofield_transform(J, beta::Float64, mu::Float64) #spectral function, inverse temp, chemical potential
    """thermofield purification using fermi function ancilla"""
    fermi(k) = 1/(1 + exp(beta*k - beta*mu))
    J1 = w -> J(w) * fermi(w) #filled mode spectral density
    J2 = w -> J(w) * (1 - fermi(w)) #empty mode spectral density
    return J1, J2
end

function chain_map(J, N::Int64, D::Float64)
    """calculates family of monic orthogonal polynomials w.r.t the measure J(x) up to the Nth term.
    returns the coefficients alpha and beta from the recurrence relation of the family."""
    supp = (-D, D)
    meas = Measure("bath", J, supp, false, Dict())
    ortho_poly = OrthoPoly("bath_op", N, meas; Nquad=10000)   
    chain = coeffs(ortho_poly)                                  
    Es = chain[1:N,1] #site energies
    ts = sqrt.(chain[1:N,2]) #site hoppings (first term is system hopping)
    return Es, ts
end

function prepare_2body_MPS(N::Int64, sys_state::Vector{String})
    """
    Prepare initial MPS state for 2-body system + Bath
    Sites 1 & 2: System
    Sites 3 to N+2: Filled chain
    Sites N+3 to 2N+2: Empty chain
    """
    
    # Using "Fermion" sites as in your snippet, conserving particle number
    sites = siteinds("Fermion", 2N+2, conserve_qns=true)
    
    # Initialize state array
    # Default: Bath is empty ("Emp"), System is set by sys_state
    states = ["Occ" for _ in 1:2N+2]
    states[4:2:2N+2] .= "Emp"
    
    # Set System States (Site 1 and 2)
    states[1] = sys_state[1]
    states[2] = sys_state[2]
    
    # Optional: Fill half the bath if needed (Fermi sea)
    # for j in 3:2:N_total
    #     states[j] = "Occ"
    # end

    psi0 = MPS(sites, states) 
    return psi0, sites, states
end

function HamiltonianMPO(E_sys, t_sys, V_sys, E1, t1, E2, t2, sites, N)
    
    """
    1 - filled chain
    2 - empty chain

    Fermionic Hamiltonian for 2-body system coupled to a bath chain
    System: Sites 1, 2
    Bath: Sites 3...2N+2
    """

    N_total = length(sites)
    ampo = AutoMPO() 
    
    # --- 1. Internal System Dynamics (Sites 1 & 2) ---
    # Hopping between the two bodies
    add!(ampo, E_sys[1], "N", 1)
    add!(ampo, E_sys[2], "N", 2)

    add!(ampo, t_sys, "Cdag", 1, "C", 2)
    add!(ampo, t_sys, "Cdag", 2, "C", 1)
    
    # Interaction term (e.g., Coulomb repulsion V * n1 * n2)
    add!(ampo, V_sys, "N", 1, "N", 2)
    
    #system-filled chain coupling
    add!(ampo, t1[1], "Cdag", 2, "C", 3)
    add!(ampo, t1[1], "Cdag", 3, "C", 2)

    #system-empty chain coupling
    add!(ampo, t2[1], "Cdag", 2, "C", 4)
    add!(ampo, t2[1], "Cdag", 4, "C", 2)
    
    for j in 1:N
        add!(ampo, E1[j], "N", 2 + 2j-1)
        add!(ampo, E2[j], "N", 2 + 2j)
    end
    for j in 2:N
        add!(ampo, t1[j], "Cdag", 2j-1, "C", 2j+1 )
        add!(ampo, t1[j], "Cdag", 2j+1, "C", 2j-1)
        add!(ampo, t2[j], "Cdag", 2j, "C", 2j+2)
        add!(ampo, t2[j], "Cdag", 2j+2, "C", 2j)
    end
    return MPO(ampo, sites)
end

function evolve_MPS(psi0::MPS, H::MPO, dt::Float64, tmax::Float64)
    """Time evolve MPS with Hamiltonian MPO using TDVP"""
    psi = psi0
    ts = collect(dt:dt:tmax)
    len = length(ts)
    nSys1 = zeros(len)
    nSys2 = zeros(len)
    num = zeros(2N+1)
    for k in 1:len
        psi = tdvp(H, -im*dt, psi; nsite=2, outputlevel=1, mindim=1, maxdim=1000) #time_step=dt, nsweeps=sweeps, order=2)
        nSys1[k] = expect(psi, "N"; sites=1)[1]
        nSys2[k] = expect(psi, "N"; sites=2)[1]
        println("timestep $k of $len complete")
    end
    return nSys1, nSys2
end
# Out:
# evolve_MPS (generic function with 1 method)

# %%
D = 1.0
mu = 0.0
N = 30
g = 0.1
beta = 10.0

E_sys = [0.0, 0.0] #system site energies
t_sys = 0.1 #system site hopping
V_sys = 0.0 #coulomb repulsion

dt = 0.1
tmax = 50.0


J = spectral_func("elliptical", D, g)
J1, J2 = thermofield_transform(J, beta, mu)
E1, t1 = chain_map(J1, N, D)
E2, t2 = chain_map(J2, N, D)

psi0, sites, states = prepare_2body_MPS(N, ["Occ", "Emp"])
H = HamiltonianMPO(E_sys, t_sys, V_sys, E1, t1, E2, t2, sites, N)

nSys1, nSys2 = evolve_MPS(psi0, H, dt, tmax)
# Out:
# After sweep 1: maxlinkdim=4 maxerr=1.23E-16 current_time=0.0 - 0.1im time=42.913
# timestep 1 of 500 complete
# After sweep 1: maxlinkdim=5 maxerr=8.55E-18 current_time=0.0 - 0.1im time=1.309
# timestep 2 of 500 complete
# After sweep 1: maxlinkdim=5 maxerr=1.48E-16 current_time=0.0 - 0.1im time=0.104
# timestep 3 of 500 complete
# After sweep 1: maxlinkdim=5 maxerr=5.35E-18 current_time=0.0 - 0.1im time=0.11
# timestep 4 of 500 complete
# After sweep 1: maxlinkdim=5 maxerr=1.28E-16 current_time=0.0 - 0.1im time=0.131
# timestep 5 of 500 complete
# After sweep 1: maxlinkdim=5 maxerr=4.23E-17 current_time=0.0 - 0.1im time=0.156
# timestep 6 of 500 complete
# After sweep 1: maxlinkdim=6 maxerr=2.05E-16 current_time=0.0 - 0.1im time=0.88
# timestep 7 of 500 complete
# After sweep 1: maxlinkdim=7 maxerr=1.85E-16 current_time=0.0 - 0.1im time=0.24
# timestep 8 of 500 complete
# After sweep 1: maxlinkdim=7 maxerr=1.74E-16 current_time=0.0 - 0.1im time=0.267
# timestep 9 of 500 complete
# After sweep 1: maxlinkdim=7 maxerr=4.34E-17 current_time=0.0 - 0.1im time=0.285
# timestep 10 of 500 complete
# After sweep 1: maxlinkdim=7 maxerr=1.50E-16 current_time=0.0 - 0.1im time=0.316
# timestep 11 of 500 complete
# After sweep 1: maxlinkdim=8 maxerr=2.19E-16 current_time=0.0 - 0.1im time=0.358
# timestep 12 of 500 complete
# After sweep 1: maxlinkdim=9 maxerr=3.60E-17 current_time=0.0 - 0.1im time=0.37
# timestep 13 of 500 complete
# After sweep 1: maxlinkdim=9 maxerr=1.01E-16 current_time=0.0 - 0.1im time=0.4
# timestep 14 of 500 complete
# After sweep 1: maxlinkdim=9 maxerr=2.21E-16 current_time=0.0 - 0.1im time=0.395
# timestep 15 of 500 complete
# After sweep 1: maxlinkdim=9 maxerr=1.27E-16 current_time=0.0 - 0.1im time=0.437
# timestep 16 of 500 complete
# After sweep 1: maxlinkdim=9 maxerr=1.47E-16 current_time=0.0 - 0.1im time=0.473
# timestep 17 of 500 complete
# After sweep 1: maxlinkdim=10 maxerr=2.16E-16 current_time=0.0 - 0.1im time=0.49
# timestep 18 of 500 complete
# After sweep 1: maxlinkdim=11 maxerr=1.92E-16 current_time=0.0 - 0.1im time=0.527
# timestep 19 of 500 complete
# After sweep 1: maxlinkdim=11 maxerr=1.52E-16 current_time=0.0 - 0.1im time=0.562
# timestep 20 of 500 complete
# After sweep 1: maxlinkdim=11 maxerr=1.63E-16 current_time=0.0 - 0.1im time=0.615
# timestep 21 of 500 complete
# After sweep 1: maxlinkdim=11 maxerr=4.66E-17 current_time=0.0 - 0.1im time=0.634
# timestep 22 of 500 complete
# After sweep 1: maxlinkdim=11 maxerr=9.54E-17 current_time=0.0 - 0.1im time=0.636
# timestep 23 of 500 complete
# After sweep 1: maxlinkdim=11 maxerr=1.99E-16 current_time=0.0 - 0.1im time=0.645
# timestep 24 of 500 complete
# After sweep 1: maxlinkdim=12 maxerr=2.03E-16 current_time=0.0 - 0.1im time=0.691
# timestep 25 of 500 complete
# After sweep 1: maxlinkdim=12 maxerr=1.58E-16 current_time=0.0 - 0.1im time=0.707
# timestep 26 of 500 complete
# After sweep 1: maxlinkdim=13 maxerr=2.14E-16 current_time=0.0 - 0.1im time=0.717
# timestep 27 of 500 complete
# After sweep 1: maxlinkdim=13 maxerr=1.89E-16 current_time=0.0 - 0.1im time=0.761
# timestep 28 of 500 complete
# After sweep 1: maxlinkdim=13 maxerr=1.71E-16 current_time=0.0 - 0.1im time=0.805
# timestep 29 of 500 complete
# After sweep 1: maxlinkdim=13 maxerr=2.12E-16 current_time=0.0 - 0.1im time=0.867
# timestep 30 of 500 complete
# After sweep 1: maxlinkdim=13 maxerr=2.12E-16 current_time=0.0 - 0.1im time=0.907
# timestep 31 of 500 complete
# After sweep 1: maxlinkdim=14 maxerr=1.81E-16 current_time=0.0 - 0.1im time=0.92
# timestep 32 of 500 complete
# After sweep 1: maxlinkdim=15 maxerr=2.04E-16 current_time=0.0 - 0.1im time=0.919
# timestep 33 of 500 complete
# After sweep 1: maxlinkdim=15 maxerr=1.95E-16 current_time=0.0 - 0.1im time=0.936
# timestep 34 of 500 complete
# After sweep 1: maxlinkdim=15 maxerr=1.72E-16 current_time=0.0 - 0.1im time=0.971
# timestep 35 of 500 complete
# After sweep 1: maxlinkdim=16 maxerr=1.42E-16 current_time=0.0 - 0.1im time=1.002
# timestep 36 of 500 complete
# After sweep 1: maxlinkdim=16 maxerr=1.86E-16 current_time=0.0 - 0.1im time=1.014
# timestep 37 of 500 complete
# After sweep 1: maxlinkdim=16 maxerr=2.11E-16 current_time=0.0 - 0.1im time=1.031
# timestep 38 of 500 complete
# After sweep 1: maxlinkdim=17 maxerr=2.14E-16 current_time=0.0 - 0.1im time=1.055
# timestep 39 of 500 complete
# After sweep 1: maxlinkdim=17 maxerr=2.12E-16 current_time=0.0 - 0.1im time=1.117
# timestep 40 of 500 complete
# After sweep 1: maxlinkdim=18 maxerr=2.20E-16 current_time=0.0 - 0.1im time=1.144
# timestep 41 of 500 complete
# After sweep 1: maxlinkdim=18 maxerr=1.16E-16 current_time=0.0 - 0.1im time=1.181
# timestep 42 of 500 complete
# After sweep 1: maxlinkdim=18 maxerr=2.07E-16 current_time=0.0 - 0.1im time=1.217
# timestep 43 of 500 complete
# After sweep 1: maxlinkdim=18 maxerr=1.79E-16 current_time=0.0 - 0.1im time=1.24
# timestep 44 of 500 complete
# After sweep 1: maxlinkdim=19 maxerr=2.05E-16 current_time=0.0 - 0.1im time=1.298
# timestep 45 of 500 complete
# After sweep 1: maxlinkdim=19 maxerr=2.14E-16 current_time=0.0 - 0.1im time=1.318
# timestep 46 of 500 complete
# After sweep 1: maxlinkdim=20 maxerr=2.22E-16 current_time=0.0 - 0.1im time=1.322
# timestep 47 of 500 complete
# After sweep 1: maxlinkdim=20 maxerr=1.26E-16 current_time=0.0 - 0.1im time=1.354
# timestep 48 of 500 complete
# After sweep 1: maxlinkdim=21 maxerr=2.18E-16 current_time=0.0 - 0.1im time=1.392
# timestep 49 of 500 complete
# After sweep 1: maxlinkdim=22 maxerr=2.16E-16 current_time=0.0 - 0.1im time=1.452
# timestep 50 of 500 complete
# After sweep 1: maxlinkdim=22 maxerr=1.82E-16 current_time=0.0 - 0.1im time=1.489
# timestep 51 of 500 complete
# After sweep 1: maxlinkdim=22 maxerr=1.70E-16 current_time=0.0 - 0.1im time=1.586
# timestep 52 of 500 complete
# After sweep 1: maxlinkdim=23 maxerr=2.14E-16 current_time=0.0 - 0.1im time=1.464
# timestep 53 of 500 complete
# After sweep 1: maxlinkdim=23 maxerr=2.16E-16 current_time=0.0 - 0.1im time=1.521
# timestep 54 of 500 complete
# After sweep 1: maxlinkdim=24 maxerr=2.21E-16 current_time=0.0 - 0.1im time=1.565
# timestep 55 of 500 complete
# After sweep 1: maxlinkdim=25 maxerr=2.10E-16 current_time=0.0 - 0.1im time=1.607
# timestep 56 of 500 complete
# After sweep 1: maxlinkdim=25 maxerr=2.15E-16 current_time=0.0 - 0.1im time=1.644
# timestep 57 of 500 complete
# After sweep 1: maxlinkdim=26 maxerr=1.83E-16 current_time=0.0 - 0.1im time=1.665
# timestep 58 of 500 complete
# After sweep 1: maxlinkdim=27 maxerr=1.82E-16 current_time=0.0 - 0.1im time=1.711
# timestep 59 of 500 complete
# After sweep 1: maxlinkdim=27 maxerr=1.97E-16 current_time=0.0 - 0.1im time=1.743
# timestep 60 of 500 complete
# After sweep 1: maxlinkdim=28 maxerr=2.12E-16 current_time=0.0 - 0.1im time=1.772
# timestep 61 of 500 complete
# After sweep 1: maxlinkdim=28 maxerr=1.78E-16 current_time=0.0 - 0.1im time=1.832
# timestep 62 of 500 complete
# After sweep 1: maxlinkdim=28 maxerr=2.06E-16 current_time=0.0 - 0.1im time=1.83
# timestep 63 of 500 complete
# After sweep 1: maxlinkdim=29 maxerr=1.64E-16 current_time=0.0 - 0.1im time=1.949
# timestep 64 of 500 complete
# After sweep 1: maxlinkdim=29 maxerr=2.05E-16 current_time=0.0 - 0.1im time=1.949
# timestep 65 of 500 complete
# After sweep 1: maxlinkdim=30 maxerr=2.02E-16 current_time=0.0 - 0.1im time=2.01
# timestep 66 of 500 complete
# After sweep 1: maxlinkdim=30 maxerr=2.14E-16 current_time=0.0 - 0.1im time=1.952
# timestep 67 of 500 complete
# After sweep 1: maxlinkdim=32 maxerr=2.18E-16 current_time=0.0 - 0.1im time=1.982
# timestep 68 of 500 complete
# After sweep 1: maxlinkdim=32 maxerr=2.19E-16 current_time=0.0 - 0.1im time=2.032
# timestep 69 of 500 complete
# After sweep 1: maxlinkdim=32 maxerr=2.18E-16 current_time=0.0 - 0.1im time=2.079
# timestep 70 of 500 complete
# After sweep 1: maxlinkdim=32 maxerr=2.09E-16 current_time=0.0 - 0.1im time=2.09
# timestep 71 of 500 complete
# After sweep 1: maxlinkdim=34 maxerr=2.12E-16 current_time=0.0 - 0.1im time=2.134
# timestep 72 of 500 complete
# After sweep 1: maxlinkdim=35 maxerr=2.17E-16 current_time=0.0 - 0.1im time=2.187
# timestep 73 of 500 complete
# After sweep 1: maxlinkdim=36 maxerr=1.97E-16 current_time=0.0 - 0.1im time=2.338
# timestep 74 of 500 complete
# After sweep 1: maxlinkdim=36 maxerr=2.17E-16 current_time=0.0 - 0.1im time=2.247
# timestep 75 of 500 complete
# After sweep 1: maxlinkdim=36 maxerr=2.21E-16 current_time=0.0 - 0.1im time=2.289
# timestep 76 of 500 complete
# After sweep 1: maxlinkdim=37 maxerr=2.17E-16 current_time=0.0 - 0.1im time=2.318
# timestep 77 of 500 complete
# After sweep 1: maxlinkdim=37 maxerr=2.16E-16 current_time=0.0 - 0.1im time=2.389
# timestep 78 of 500 complete
# After sweep 1: maxlinkdim=38 maxerr=2.13E-16 current_time=0.0 - 0.1im time=2.429
# timestep 79 of 500 complete
# After sweep 1: maxlinkdim=39 maxerr=1.85E-16 current_time=0.0 - 0.1im time=2.528
# timestep 80 of 500 complete
# After sweep 1: maxlinkdim=40 maxerr=2.13E-16 current_time=0.0 - 0.1im time=2.456
# timestep 81 of 500 complete
# After sweep 1: maxlinkdim=40 maxerr=2.08E-16 current_time=0.0 - 0.1im time=2.551
# timestep 82 of 500 complete
# After sweep 1: maxlinkdim=40 maxerr=2.11E-16 current_time=0.0 - 0.1im time=2.595
# timestep 83 of 500 complete
# After sweep 1: maxlinkdim=41 maxerr=2.21E-16 current_time=0.0 - 0.1im time=2.764
# timestep 84 of 500 complete
# After sweep 1: maxlinkdim=42 maxerr=2.14E-16 current_time=0.0 - 0.1im time=2.695
# timestep 85 of 500 complete
# After sweep 1: maxlinkdim=43 maxerr=2.21E-16 current_time=0.0 - 0.1im time=2.712
# timestep 86 of 500 complete
# After sweep 1: maxlinkdim=44 maxerr=2.06E-16 current_time=0.0 - 0.1im time=2.762
# timestep 87 of 500 complete
# After sweep 1: maxlinkdim=45 maxerr=1.98E-16 current_time=0.0 - 0.1im time=2.907
# timestep 88 of 500 complete
# After sweep 1: maxlinkdim=45 maxerr=1.95E-16 current_time=0.0 - 0.1im time=2.831
# timestep 89 of 500 complete
# After sweep 1: maxlinkdim=46 maxerr=2.21E-16 current_time=0.0 - 0.1im time=2.857
# timestep 90 of 500 complete
# After sweep 1: maxlinkdim=46 maxerr=2.15E-16 current_time=0.0 - 0.1im time=2.897
# timestep 91 of 500 complete
# After sweep 1: maxlinkdim=47 maxerr=2.13E-16 current_time=0.0 - 0.1im time=3.03
# timestep 92 of 500 complete
# After sweep 1: maxlinkdim=49 maxerr=2.21E-16 current_time=0.0 - 0.1im time=3.017
# timestep 93 of 500 complete
# After sweep 1: maxlinkdim=49 maxerr=2.18E-16 current_time=0.0 - 0.1im time=3.127
# timestep 94 of 500 complete
# After sweep 1: maxlinkdim=50 maxerr=2.22E-16 current_time=0.0 - 0.1im time=3.241
# timestep 95 of 500 complete
# After sweep 1: maxlinkdim=51 maxerr=2.08E-16 current_time=0.0 - 0.1im time=3.231
# timestep 96 of 500 complete
# After sweep 1: maxlinkdim=51 maxerr=2.21E-16 current_time=0.0 - 0.1im time=3.385
# timestep 97 of 500 complete
# After sweep 1: maxlinkdim=52 maxerr=2.16E-16 current_time=0.0 - 0.1im time=3.299
# timestep 98 of 500 complete
# After sweep 1: maxlinkdim=54 maxerr=2.01E-16 current_time=0.0 - 0.1im time=3.36
# timestep 99 of 500 complete
# After sweep 1: maxlinkdim=54 maxerr=2.19E-16 current_time=0.0 - 0.1im time=3.462
# timestep 100 of 500 complete
# After sweep 1: maxlinkdim=54 maxerr=2.15E-16 current_time=0.0 - 0.1im time=3.434
# timestep 101 of 500 complete
# After sweep 1: maxlinkdim=55 maxerr=2.08E-16 current_time=0.0 - 0.1im time=3.608
# timestep 102 of 500 complete
# After sweep 1: maxlinkdim=56 maxerr=2.12E-16 current_time=0.0 - 0.1im time=3.549
# timestep 103 of 500 complete
# After sweep 1: maxlinkdim=57 maxerr=2.18E-16 current_time=0.0 - 0.1im time=3.736
# timestep 104 of 500 complete
# After sweep 1: maxlinkdim=58 maxerr=2.19E-16 current_time=0.0 - 0.1im time=3.746
# timestep 105 of 500 complete
# After sweep 1: maxlinkdim=58 maxerr=2.21E-16 current_time=0.0 - 0.1im time=3.942
# timestep 106 of 500 complete
# After sweep 1: maxlinkdim=59 maxerr=2.16E-16 current_time=0.0 - 0.1im time=3.893
# timestep 107 of 500 complete
# After sweep 1: maxlinkdim=59 maxerr=2.16E-16 current_time=0.0 - 0.1im time=4.179
# timestep 108 of 500 complete
# After sweep 1: maxlinkdim=60 maxerr=2.10E-16 current_time=0.0 - 0.1im time=4.292
# timestep 109 of 500 complete
# After sweep 1: maxlinkdim=61 maxerr=2.18E-16 current_time=0.0 - 0.1im time=4.16
# timestep 110 of 500 complete
# After sweep 1: maxlinkdim=62 maxerr=2.15E-16 current_time=0.0 - 0.1im time=4.434
# timestep 111 of 500 complete
# After sweep 1: maxlinkdim=63 maxerr=2.19E-16 current_time=0.0 - 0.1im time=4.833
# timestep 112 of 500 complete
# After sweep 1: maxlinkdim=64 maxerr=2.22E-16 current_time=0.0 - 0.1im time=4.819
# timestep 113 of 500 complete
# After sweep 1: maxlinkdim=65 maxerr=2.07E-16 current_time=0.0 - 0.1im time=4.917
# timestep 114 of 500 complete
# After sweep 1: maxlinkdim=66 maxerr=2.20E-16 current_time=0.0 - 0.1im time=4.891
# timestep 115 of 500 complete
# After sweep 1: maxlinkdim=66 maxerr=2.18E-16 current_time=0.0 - 0.1im time=4.872
# timestep 116 of 500 complete
# After sweep 1: maxlinkdim=67 maxerr=2.20E-16 current_time=0.0 - 0.1im time=4.811
# timestep 117 of 500 complete
# After sweep 1: maxlinkdim=68 maxerr=2.21E-16 current_time=0.0 - 0.1im time=5.04
# timestep 118 of 500 complete
# After sweep 1: maxlinkdim=69 maxerr=2.20E-16 current_time=0.0 - 0.1im time=5.109
# timestep 119 of 500 complete
# After sweep 1: maxlinkdim=71 maxerr=2.19E-16 current_time=0.0 - 0.1im time=5.159
# timestep 120 of 500 complete
# After sweep 1: maxlinkdim=72 maxerr=2.20E-16 current_time=0.0 - 0.1im time=5.277
# timestep 121 of 500 complete
# After sweep 1: maxlinkdim=73 maxerr=2.21E-16 current_time=0.0 - 0.1im time=5.364
# timestep 122 of 500 complete
# After sweep 1: maxlinkdim=74 maxerr=2.20E-16 current_time=0.0 - 0.1im time=5.496
# timestep 123 of 500 complete
# After sweep 1: maxlinkdim=75 maxerr=2.18E-16 current_time=0.0 - 0.1im time=5.622
# timestep 124 of 500 complete
# After sweep 1: maxlinkdim=76 maxerr=2.18E-16 current_time=0.0 - 0.1im time=5.74
# timestep 125 of 500 complete
# After sweep 1: maxlinkdim=77 maxerr=2.21E-16 current_time=0.0 - 0.1im time=5.781
# timestep 126 of 500 complete
# After sweep 1: maxlinkdim=78 maxerr=2.12E-16 current_time=0.0 - 0.1im time=6.066
# timestep 127 of 500 complete
# After sweep 1: maxlinkdim=79 maxerr=2.19E-16 current_time=0.0 - 0.1im time=6.138
# timestep 128 of 500 complete
# After sweep 1: maxlinkdim=79 maxerr=2.22E-16 current_time=0.0 - 0.1im time=6.3
# timestep 129 of 500 complete
# After sweep 1: maxlinkdim=80 maxerr=2.21E-16 current_time=0.0 - 0.1im time=6.629
# timestep 130 of 500 complete
# After sweep 1: maxlinkdim=81 maxerr=2.20E-16 current_time=0.0 - 0.1im time=6.274
# timestep 131 of 500 complete
# After sweep 1: maxlinkdim=82 maxerr=2.22E-16 current_time=0.0 - 0.1im time=6.192
# timestep 132 of 500 complete
# After sweep 1: maxlinkdim=82 maxerr=2.08E-16 current_time=0.0 - 0.1im time=6.392
# timestep 133 of 500 complete
# After sweep 1: maxlinkdim=83 maxerr=2.17E-16 current_time=0.0 - 0.1im time=6.547
# timestep 134 of 500 complete
# After sweep 1: maxlinkdim=84 maxerr=2.21E-16 current_time=0.0 - 0.1im time=6.627
# timestep 135 of 500 complete
# After sweep 1: maxlinkdim=85 maxerr=2.17E-16 current_time=0.0 - 0.1im time=6.905
# timestep 136 of 500 complete
# After sweep 1: maxlinkdim=85 maxerr=2.21E-16 current_time=0.0 - 0.1im time=6.797
# timestep 137 of 500 complete
# After sweep 1: maxlinkdim=86 maxerr=2.19E-16 current_time=0.0 - 0.1im time=8.149
# timestep 138 of 500 complete
# After sweep 1: maxlinkdim=87 maxerr=2.20E-16 current_time=0.0 - 0.1im time=8.756
# timestep 139 of 500 complete
# After sweep 1: maxlinkdim=88 maxerr=2.20E-16 current_time=0.0 - 0.1im time=7.682
# timestep 140 of 500 complete
# After sweep 1: maxlinkdim=90 maxerr=2.22E-16 current_time=0.0 - 0.1im time=7.591
# timestep 141 of 500 complete
# After sweep 1: maxlinkdim=91 maxerr=2.18E-16 current_time=0.0 - 0.1im time=7.824
# timestep 142 of 500 complete
# After sweep 1: maxlinkdim=91 maxerr=2.22E-16 current_time=0.0 - 0.1im time=8.141
# timestep 143 of 500 complete
# After sweep 1: maxlinkdim=93 maxerr=2.22E-16 current_time=0.0 - 0.1im time=7.902
# timestep 144 of 500 complete
# After sweep 1: maxlinkdim=93 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.033
# timestep 145 of 500 complete
# After sweep 1: maxlinkdim=94 maxerr=2.18E-16 current_time=0.0 - 0.1im time=8.101
# timestep 146 of 500 complete
# After sweep 1: maxlinkdim=95 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.138
# timestep 147 of 500 complete
# After sweep 1: maxlinkdim=96 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.356
# timestep 148 of 500 complete
# After sweep 1: maxlinkdim=97 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.506
# timestep 149 of 500 complete
# After sweep 1: maxlinkdim=98 maxerr=2.16E-16 current_time=0.0 - 0.1im time=8.462
# timestep 150 of 500 complete
# After sweep 1: maxlinkdim=99 maxerr=2.18E-16 current_time=0.0 - 0.1im time=8.645
# timestep 151 of 500 complete
# After sweep 1: maxlinkdim=100 maxerr=2.20E-16 current_time=0.0 - 0.1im time=8.209
# timestep 152 of 500 complete
# After sweep 1: maxlinkdim=101 maxerr=2.22E-16 current_time=0.0 - 0.1im time=8.297
# timestep 153 of 500 complete
# After sweep 1: maxlinkdim=102 maxerr=2.19E-16 current_time=0.0 - 0.1im time=8.523
# timestep 154 of 500 complete
# After sweep 1: maxlinkdim=103 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.821
# timestep 155 of 500 complete
# After sweep 1: maxlinkdim=105 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.333
# timestep 156 of 500 complete
# After sweep 1: maxlinkdim=106 maxerr=2.14E-16 current_time=0.0 - 0.1im time=8.416
# timestep 157 of 500 complete
# After sweep 1: maxlinkdim=107 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.44
# timestep 158 of 500 complete
# After sweep 1: maxlinkdim=108 maxerr=2.22E-16 current_time=0.0 - 0.1im time=8.795
# timestep 159 of 500 complete
# After sweep 1: maxlinkdim=110 maxerr=2.22E-16 current_time=0.0 - 0.1im time=8.673
# timestep 160 of 500 complete
# After sweep 1: maxlinkdim=111 maxerr=2.21E-16 current_time=0.0 - 0.1im time=8.75
# timestep 161 of 500 complete
# After sweep 1: maxlinkdim=112 maxerr=2.14E-16 current_time=0.0 - 0.1im time=8.924
# timestep 162 of 500 complete
# After sweep 1: maxlinkdim=113 maxerr=2.20E-16 current_time=0.0 - 0.1im time=9.105
# timestep 163 of 500 complete
# After sweep 1: maxlinkdim=114 maxerr=2.20E-16 current_time=0.0 - 0.1im time=9.178
# timestep 164 of 500 complete
# After sweep 1: maxlinkdim=116 maxerr=2.22E-16 current_time=0.0 - 0.1im time=9.275
# timestep 165 of 500 complete
# After sweep 1: maxlinkdim=117 maxerr=2.20E-16 current_time=0.0 - 0.1im time=9.429
# timestep 166 of 500 complete
# After sweep 1: maxlinkdim=118 maxerr=2.21E-16 current_time=0.0 - 0.1im time=9.609
# timestep 167 of 500 complete
# After sweep 1: maxlinkdim=119 maxerr=2.21E-16 current_time=0.0 - 0.1im time=9.758
# timestep 168 of 500 complete
# After sweep 1: maxlinkdim=121 maxerr=2.20E-16 current_time=0.0 - 0.1im time=9.981
# timestep 169 of 500 complete
# After sweep 1: maxlinkdim=123 maxerr=2.20E-16 current_time=0.0 - 0.1im time=10.033
# timestep 170 of 500 complete
# After sweep 1: maxlinkdim=124 maxerr=2.19E-16 current_time=0.0 - 0.1im time=10.109
# timestep 171 of 500 complete
# After sweep 1: maxlinkdim=125 maxerr=2.21E-16 current_time=0.0 - 0.1im time=10.327
# timestep 172 of 500 complete
# After sweep 1: maxlinkdim=127 maxerr=2.21E-16 current_time=0.0 - 0.1im time=10.428
# timestep 173 of 500 complete
# After sweep 1: maxlinkdim=128 maxerr=2.21E-16 current_time=0.0 - 0.1im time=10.587
# timestep 174 of 500 complete
# After sweep 1: maxlinkdim=129 maxerr=2.18E-16 current_time=0.0 - 0.1im time=10.783
# timestep 175 of 500 complete
# After sweep 1: maxlinkdim=130 maxerr=2.20E-16 current_time=0.0 - 0.1im time=11.125
# timestep 176 of 500 complete
# After sweep 1: maxlinkdim=131 maxerr=2.19E-16 current_time=0.0 - 0.1im time=11.958
# timestep 177 of 500 complete
# After sweep 1: maxlinkdim=131 maxerr=2.22E-16 current_time=0.0 - 0.1im time=12.535
# timestep 178 of 500 complete
# After sweep 1: maxlinkdim=132 maxerr=2.21E-16 current_time=0.0 - 0.1im time=12.713
# timestep 179 of 500 complete
# After sweep 1: maxlinkdim=133 maxerr=2.22E-16 current_time=0.0 - 0.1im time=12.764
# timestep 180 of 500 complete
# After sweep 1: maxlinkdim=134 maxerr=2.21E-16 current_time=0.0 - 0.1im time=13.319
# timestep 181 of 500 complete
# After sweep 1: maxlinkdim=135 maxerr=2.21E-16 current_time=0.0 - 0.1im time=13.348
# timestep 182 of 500 complete
# After sweep 1: maxlinkdim=136 maxerr=2.21E-16 current_time=0.0 - 0.1im time=13.334
# timestep 183 of 500 complete
# After sweep 1: maxlinkdim=137 maxerr=2.19E-16 current_time=0.0 - 0.1im time=13.815
# timestep 184 of 500 complete
# After sweep 1: maxlinkdim=139 maxerr=2.22E-16 current_time=0.0 - 0.1im time=14.193
# timestep 185 of 500 complete
# After sweep 1: maxlinkdim=139 maxerr=2.20E-16 current_time=0.0 - 0.1im time=14.515
# timestep 186 of 500 complete
# After sweep 1: maxlinkdim=140 maxerr=2.22E-16 current_time=0.0 - 0.1im time=14.637
# timestep 187 of 500 complete
# After sweep 1: maxlinkdim=142 maxerr=2.16E-16 current_time=0.0 - 0.1im time=14.705
# timestep 188 of 500 complete
# After sweep 1: maxlinkdim=143 maxerr=2.22E-16 current_time=0.0 - 0.1im time=15.256
# timestep 189 of 500 complete
# After sweep 1: maxlinkdim=144 maxerr=2.15E-16 current_time=0.0 - 0.1im time=15.367
# timestep 190 of 500 complete
# After sweep 1: maxlinkdim=146 maxerr=2.20E-16 current_time=0.0 - 0.1im time=15.976
# timestep 191 of 500 complete
# After sweep 1: maxlinkdim=147 maxerr=2.22E-16 current_time=0.0 - 0.1im time=15.735
# timestep 192 of 500 complete
# After sweep 1: maxlinkdim=148 maxerr=2.21E-16 current_time=0.0 - 0.1im time=15.964
# timestep 193 of 500 complete
# After sweep 1: maxlinkdim=149 maxerr=2.19E-16 current_time=0.0 - 0.1im time=16.492
# timestep 194 of 500 complete
# After sweep 1: maxlinkdim=150 maxerr=2.20E-16 current_time=0.0 - 0.1im time=16.535
# timestep 195 of 500 complete
# After sweep 1: maxlinkdim=151 maxerr=2.22E-16 current_time=0.0 - 0.1im time=16.913
# timestep 196 of 500 complete
# After sweep 1: maxlinkdim=152 maxerr=2.21E-16 current_time=0.0 - 0.1im time=18.483
# timestep 197 of 500 complete
# After sweep 1: maxlinkdim=152 maxerr=2.21E-16 current_time=0.0 - 0.1im time=18.373
# timestep 198 of 500 complete
# After sweep 1: maxlinkdim=153 maxerr=2.20E-16 current_time=0.0 - 0.1im time=18.253
# timestep 199 of 500 complete
# After sweep 1: maxlinkdim=154 maxerr=2.21E-16 current_time=0.0 - 0.1im time=17.965
# timestep 200 of 500 complete
# After sweep 1: maxlinkdim=155 maxerr=2.21E-16 current_time=0.0 - 0.1im time=18.19
# timestep 201 of 500 complete
# After sweep 1: maxlinkdim=156 maxerr=2.21E-16 current_time=0.0 - 0.1im time=18.415
# timestep 202 of 500 complete
# After sweep 1: maxlinkdim=157 maxerr=2.21E-16 current_time=0.0 - 0.1im time=18.814
# timestep 203 of 500 complete
# After sweep 1: maxlinkdim=158 maxerr=2.21E-16 current_time=0.0 - 0.1im time=18.668
# timestep 204 of 500 complete
# After sweep 1: maxlinkdim=159 maxerr=2.21E-16 current_time=0.0 - 0.1im time=19.959
# timestep 205 of 500 complete
# After sweep 1: maxlinkdim=160 maxerr=2.21E-16 current_time=0.0 - 0.1im time=19.925
# timestep 206 of 500 complete
# After sweep 1: maxlinkdim=160 maxerr=2.21E-16 current_time=0.0 - 0.1im time=19.688
# timestep 207 of 500 complete
# After sweep 1: maxlinkdim=161 maxerr=2.21E-16 current_time=0.0 - 0.1im time=20.56
# timestep 208 of 500 complete
# After sweep 1: maxlinkdim=163 maxerr=2.21E-16 current_time=0.0 - 0.1im time=20.419
# timestep 209 of 500 complete
# After sweep 1: maxlinkdim=164 maxerr=2.21E-16 current_time=0.0 - 0.1im time=20.864
# timestep 210 of 500 complete
# After sweep 1: maxlinkdim=165 maxerr=2.21E-16 current_time=0.0 - 0.1im time=21.293
# timestep 211 of 500 complete
# After sweep 1: maxlinkdim=167 maxerr=2.19E-16 current_time=0.0 - 0.1im time=20.913
# timestep 212 of 500 complete
# After sweep 1: maxlinkdim=168 maxerr=2.22E-16 current_time=0.0 - 0.1im time=22.16
# timestep 213 of 500 complete
# After sweep 1: maxlinkdim=168 maxerr=2.21E-16 current_time=0.0 - 0.1im time=22.897
# timestep 214 of 500 complete
# After sweep 1: maxlinkdim=169 maxerr=2.22E-16 current_time=0.0 - 0.1im time=23.376
# timestep 215 of 500 complete
# After sweep 1: maxlinkdim=170 maxerr=2.22E-16 current_time=0.0 - 0.1im time=23.331
# timestep 216 of 500 complete
# After sweep 1: maxlinkdim=171 maxerr=2.21E-16 current_time=0.0 - 0.1im time=23.657
# timestep 217 of 500 complete
# After sweep 1: maxlinkdim=172 maxerr=2.21E-16 current_time=0.0 - 0.1im time=21.539
# timestep 218 of 500 complete
# After sweep 1: maxlinkdim=173 maxerr=2.22E-16 current_time=0.0 - 0.1im time=21.705
# timestep 219 of 500 complete
# After sweep 1: maxlinkdim=174 maxerr=2.22E-16 current_time=0.0 - 0.1im time=22.256
# timestep 220 of 500 complete
# After sweep 1: maxlinkdim=175 maxerr=2.20E-16 current_time=0.0 - 0.1im time=22.441
# timestep 221 of 500 complete
# After sweep 1: maxlinkdim=176 maxerr=2.21E-16 current_time=0.0 - 0.1im time=22.679
# timestep 222 of 500 complete
# After sweep 1: maxlinkdim=177 maxerr=2.22E-16 current_time=0.0 - 0.1im time=23.078
# timestep 223 of 500 complete
# After sweep 1: maxlinkdim=178 maxerr=2.22E-16 current_time=0.0 - 0.1im time=23.625
# timestep 224 of 500 complete
# After sweep 1: maxlinkdim=179 maxerr=2.20E-16 current_time=0.0 - 0.1im time=23.895
# timestep 225 of 500 complete
# After sweep 1: maxlinkdim=180 maxerr=2.22E-16 current_time=0.0 - 0.1im time=24.16
# timestep 226 of 500 complete
# After sweep 1: maxlinkdim=181 maxerr=2.22E-16 current_time=0.0 - 0.1im time=24.455
# timestep 227 of 500 complete
# After sweep 1: maxlinkdim=182 maxerr=2.20E-16 current_time=0.0 - 0.1im time=24.889
# timestep 228 of 500 complete
# After sweep 1: maxlinkdim=183 maxerr=2.22E-16 current_time=0.0 - 0.1im time=25.296
# timestep 229 of 500 complete
# After sweep 1: maxlinkdim=184 maxerr=2.21E-16 current_time=0.0 - 0.1im time=25.667
# timestep 230 of 500 complete
# After sweep 1: maxlinkdim=185 maxerr=2.21E-16 current_time=0.0 - 0.1im time=25.828
# timestep 231 of 500 complete
# After sweep 1: maxlinkdim=186 maxerr=2.21E-16 current_time=0.0 - 0.1im time=26.364
# timestep 232 of 500 complete
# After sweep 1: maxlinkdim=188 maxerr=2.22E-16 current_time=0.0 - 0.1im time=26.64
# timestep 233 of 500 complete
# After sweep 1: maxlinkdim=189 maxerr=2.21E-16 current_time=0.0 - 0.1im time=27.041
# timestep 234 of 500 complete
# After sweep 1: maxlinkdim=190 maxerr=2.22E-16 current_time=0.0 - 0.1im time=27.714
# timestep 235 of 500 complete
# After sweep 1: maxlinkdim=192 maxerr=2.21E-16 current_time=0.0 - 0.1im time=28.032
# timestep 236 of 500 complete
# After sweep 1: maxlinkdim=193 maxerr=2.22E-16 current_time=0.0 - 0.1im time=28.387
# timestep 237 of 500 complete
# After sweep 1: maxlinkdim=194 maxerr=2.21E-16 current_time=0.0 - 0.1im time=28.731
# timestep 238 of 500 complete
# After sweep 1: maxlinkdim=195 maxerr=2.22E-16 current_time=0.0 - 0.1im time=29.153
# timestep 239 of 500 complete
# After sweep 1: maxlinkdim=196 maxerr=2.22E-16 current_time=0.0 - 0.1im time=29.433
# timestep 240 of 500 complete
# After sweep 1: maxlinkdim=198 maxerr=2.22E-16 current_time=0.0 - 0.1im time=30.346
# timestep 241 of 500 complete
# After sweep 1: maxlinkdim=199 maxerr=2.21E-16 current_time=0.0 - 0.1im time=31.165
# timestep 242 of 500 complete
# After sweep 1: maxlinkdim=201 maxerr=2.21E-16 current_time=0.0 - 0.1im time=30.804
# timestep 243 of 500 complete
# After sweep 1: maxlinkdim=202 maxerr=2.22E-16 current_time=0.0 - 0.1im time=31.276
# timestep 244 of 500 complete
# After sweep 1: maxlinkdim=203 maxerr=2.22E-16 current_time=0.0 - 0.1im time=32.139
# timestep 245 of 500 complete
# After sweep 1: maxlinkdim=205 maxerr=2.22E-16 current_time=0.0 - 0.1im time=32.323
# timestep 246 of 500 complete
# After sweep 1: maxlinkdim=206 maxerr=2.22E-16 current_time=0.0 - 0.1im time=32.677
# timestep 247 of 500 complete
# After sweep 1: maxlinkdim=208 maxerr=2.22E-16 current_time=0.0 - 0.1im time=33.157
# timestep 248 of 500 complete
# After sweep 1: maxlinkdim=209 maxerr=2.22E-16 current_time=0.0 - 0.1im time=33.667
# timestep 249 of 500 complete
# After sweep 1: maxlinkdim=211 maxerr=2.22E-16 current_time=0.0 - 0.1im time=34.238
# timestep 250 of 500 complete
# After sweep 1: maxlinkdim=212 maxerr=2.21E-16 current_time=0.0 - 0.1im time=34.88
# timestep 251 of 500 complete
# After sweep 1: maxlinkdim=213 maxerr=2.21E-16 current_time=0.0 - 0.1im time=35.223
# timestep 252 of 500 complete
# After sweep 1: maxlinkdim=214 maxerr=2.21E-16 current_time=0.0 - 0.1im time=38.753
# timestep 253 of 500 complete
# After sweep 1: maxlinkdim=216 maxerr=2.22E-16 current_time=0.0 - 0.1im time=38.329
# timestep 254 of 500 complete
# After sweep 1: maxlinkdim=217 maxerr=2.22E-16 current_time=0.0 - 0.1im time=38.56
# timestep 255 of 500 complete
# After sweep 1: maxlinkdim=219 maxerr=2.22E-16 current_time=0.0 - 0.1im time=39.52
# timestep 256 of 500 complete
# After sweep 1: maxlinkdim=221 maxerr=2.22E-16 current_time=0.0 - 0.1im time=39.973
# timestep 257 of 500 complete
# After sweep 1: maxlinkdim=223 maxerr=2.22E-16 current_time=0.0 - 0.1im time=40.433
# timestep 258 of 500 complete
# After sweep 1: maxlinkdim=225 maxerr=2.21E-16 current_time=0.0 - 0.1im time=41.305
# timestep 259 of 500 complete
# After sweep 1: maxlinkdim=226 maxerr=2.21E-16 current_time=0.0 - 0.1im time=41.629
# timestep 260 of 500 complete
# After sweep 1: maxlinkdim=228 maxerr=2.21E-16 current_time=0.0 - 0.1im time=42.218
# timestep 261 of 500 complete
# After sweep 1: maxlinkdim=229 maxerr=2.21E-16 current_time=0.0 - 0.1im time=42.798
# timestep 262 of 500 complete
# After sweep 1: maxlinkdim=230 maxerr=2.22E-16 current_time=0.0 - 0.1im time=43.515
# timestep 263 of 500 complete
# After sweep 1: maxlinkdim=232 maxerr=2.21E-16 current_time=0.0 - 0.1im time=43.981
# timestep 264 of 500 complete
# After sweep 1: maxlinkdim=234 maxerr=2.22E-16 current_time=0.0 - 0.1im time=44.994
# timestep 265 of 500 complete
# After sweep 1: maxlinkdim=235 maxerr=2.21E-16 current_time=0.0 - 0.1im time=45.307
# timestep 266 of 500 complete
# After sweep 1: maxlinkdim=237 maxerr=2.20E-16 current_time=0.0 - 0.1im time=45.484
# timestep 267 of 500 complete
# After sweep 1: maxlinkdim=238 maxerr=2.22E-16 current_time=0.0 - 0.1im time=46.321
# timestep 268 of 500 complete
# After sweep 1: maxlinkdim=240 maxerr=2.22E-16 current_time=0.0 - 0.1im time=46.814
# timestep 269 of 500 complete
# After sweep 1: maxlinkdim=241 maxerr=2.22E-16 current_time=0.0 - 0.1im time=47.382
# timestep 270 of 500 complete
# After sweep 1: maxlinkdim=242 maxerr=2.22E-16 current_time=0.0 - 0.1im time=47.581
# timestep 271 of 500 complete
# After sweep 1: maxlinkdim=244 maxerr=2.21E-16 current_time=0.0 - 0.1im time=48.543
# timestep 272 of 500 complete
# After sweep 1: maxlinkdim=245 maxerr=2.22E-16 current_time=0.0 - 0.1im time=48.992
# timestep 273 of 500 complete
# After sweep 1: maxlinkdim=246 maxerr=2.22E-16 current_time=0.0 - 0.1im time=49.536
# timestep 274 of 500 complete
# After sweep 1: maxlinkdim=248 maxerr=2.22E-16 current_time=0.0 - 0.1im time=50.528
# timestep 275 of 500 complete
# After sweep 1: maxlinkdim=250 maxerr=2.22E-16 current_time=0.0 - 0.1im time=53.826
# timestep 276 of 500 complete
# After sweep 1: maxlinkdim=252 maxerr=2.22E-16 current_time=0.0 - 0.1im time=51.962
# timestep 277 of 500 complete
# After sweep 1: maxlinkdim=253 maxerr=2.22E-16 current_time=0.0 - 0.1im time=52.672
# timestep 278 of 500 complete
# After sweep 1: maxlinkdim=255 maxerr=2.22E-16 current_time=0.0 - 0.1im time=53.185
# timestep 279 of 500 complete
# After sweep 1: maxlinkdim=256 maxerr=2.22E-16 current_time=0.0 - 0.1im time=54.279
# timestep 280 of 500 complete
# After sweep 1: maxlinkdim=258 maxerr=2.22E-16 current_time=0.0 - 0.1im time=54.68
# timestep 281 of 500 complete
# After sweep 1: maxlinkdim=259 maxerr=2.22E-16 current_time=0.0 - 0.1im time=55.25
# timestep 282 of 500 complete
# After sweep 1: maxlinkdim=261 maxerr=2.20E-16 current_time=0.0 - 0.1im time=55.633
# timestep 283 of 500 complete
# After sweep 1: maxlinkdim=263 maxerr=2.21E-16 current_time=0.0 - 0.1im time=56.349
# timestep 284 of 500 complete
# After sweep 1: maxlinkdim=264 maxerr=2.22E-16 current_time=0.0 - 0.1im time=57.086
# timestep 285 of 500 complete
# After sweep 1: maxlinkdim=266 maxerr=2.22E-16 current_time=0.0 - 0.1im time=57.7
# timestep 286 of 500 complete
# After sweep 1: maxlinkdim=267 maxerr=2.21E-16 current_time=0.0 - 0.1im time=58.038
# timestep 287 of 500 complete
# After sweep 1: maxlinkdim=268 maxerr=2.22E-16 current_time=0.0 - 0.1im time=58.884
# timestep 288 of 500 complete
# After sweep 1: maxlinkdim=270 maxerr=2.22E-16 current_time=0.0 - 0.1im time=59.898
# timestep 289 of 500 complete
# After sweep 1: maxlinkdim=272 maxerr=2.22E-16 current_time=0.0 - 0.1im time=60.876
# timestep 290 of 500 complete
# After sweep 1: maxlinkdim=273 maxerr=2.22E-16 current_time=0.0 - 0.1im time=61.498
# timestep 291 of 500 complete
# After sweep 1: maxlinkdim=275 maxerr=2.22E-16 current_time=0.0 - 0.1im time=62.657
# timestep 292 of 500 complete
# After sweep 1: maxlinkdim=277 maxerr=2.21E-16 current_time=0.0 - 0.1im time=63.067
# timestep 293 of 500 complete
# After sweep 1: maxlinkdim=278 maxerr=2.22E-16 current_time=0.0 - 0.1im time=63.946
# timestep 294 of 500 complete
# After sweep 1: maxlinkdim=280 maxerr=2.22E-16 current_time=0.0 - 0.1im time=63.721
# timestep 295 of 500 complete
# After sweep 1: maxlinkdim=281 maxerr=2.22E-16 current_time=0.0 - 0.1im time=68.759
# timestep 296 of 500 complete
# After sweep 1: maxlinkdim=282 maxerr=2.21E-16 current_time=0.0 - 0.1im time=69.405
# timestep 297 of 500 complete
# After sweep 1: maxlinkdim=283 maxerr=2.22E-16 current_time=0.0 - 0.1im time=70.485
# timestep 298 of 500 complete
# After sweep 1: maxlinkdim=284 maxerr=2.22E-16 current_time=0.0 - 0.1im time=71.174
# timestep 299 of 500 complete
# After sweep 1: maxlinkdim=286 maxerr=2.22E-16 current_time=0.0 - 0.1im time=71.727
# timestep 300 of 500 complete
# After sweep 1: maxlinkdim=288 maxerr=2.22E-16 current_time=0.0 - 0.1im time=72.968
# timestep 301 of 500 complete
# After sweep 1: maxlinkdim=290 maxerr=2.22E-16 current_time=0.0 - 0.1im time=74.128
# timestep 302 of 500 complete
# After sweep 1: maxlinkdim=291 maxerr=2.21E-16 current_time=0.0 - 0.1im time=75.078
# timestep 303 of 500 complete
# After sweep 1: maxlinkdim=292 maxerr=2.22E-16 current_time=0.0 - 0.1im time=76.964
# timestep 304 of 500 complete
# After sweep 1: maxlinkdim=294 maxerr=2.22E-16 current_time=0.0 - 0.1im time=75.976
# timestep 305 of 500 complete
# After sweep 1: maxlinkdim=296 maxerr=2.22E-16 current_time=0.0 - 0.1im time=74.08
# timestep 306 of 500 complete
# After sweep 1: maxlinkdim=297 maxerr=2.22E-16 current_time=0.0 - 0.1im time=74.727
# timestep 307 of 500 complete
# After sweep 1: maxlinkdim=299 maxerr=2.22E-16 current_time=0.0 - 0.1im time=76.008
# timestep 308 of 500 complete
# After sweep 1: maxlinkdim=300 maxerr=2.22E-16 current_time=0.0 - 0.1im time=77.873
# timestep 309 of 500 complete
# After sweep 1: maxlinkdim=302 maxerr=2.22E-16 current_time=0.0 - 0.1im time=77.574
# timestep 310 of 500 complete
# After sweep 1: maxlinkdim=303 maxerr=2.22E-16 current_time=0.0 - 0.1im time=78.424
# timestep 311 of 500 complete
# After sweep 1: maxlinkdim=306 maxerr=2.22E-16 current_time=0.0 - 0.1im time=79.278
# timestep 312 of 500 complete
# After sweep 1: maxlinkdim=307 maxerr=2.22E-16 current_time=0.0 - 0.1im time=80.262
# timestep 313 of 500 complete
# After sweep 1: maxlinkdim=309 maxerr=2.22E-16 current_time=0.0 - 0.1im time=80.289
# timestep 314 of 500 complete
# After sweep 1: maxlinkdim=311 maxerr=2.22E-16 current_time=0.0 - 0.1im time=77.266
# timestep 315 of 500 complete
# After sweep 1: maxlinkdim=312 maxerr=2.22E-16 current_time=0.0 - 0.1im time=78.818
# timestep 316 of 500 complete
# After sweep 1: maxlinkdim=314 maxerr=2.22E-16 current_time=0.0 - 0.1im time=79.849
# timestep 317 of 500 complete
# After sweep 1: maxlinkdim=315 maxerr=2.22E-16 current_time=0.0 - 0.1im time=81.015
# timestep 318 of 500 complete
# After sweep 1: maxlinkdim=316 maxerr=2.22E-16 current_time=0.0 - 0.1im time=81.401
# timestep 319 of 500 complete
# After sweep 1: maxlinkdim=318 maxerr=2.21E-16 current_time=0.0 - 0.1im time=82.667
# timestep 320 of 500 complete
# After sweep 1: maxlinkdim=320 maxerr=2.22E-16 current_time=0.0 - 0.1im time=83.042
# timestep 321 of 500 complete
# After sweep 1: maxlinkdim=321 maxerr=2.22E-16 current_time=0.0 - 0.1im time=84.599
# timestep 322 of 500 complete
# After sweep 1: maxlinkdim=322 maxerr=2.22E-16 current_time=0.0 - 0.1im time=84.573
# timestep 323 of 500 complete
# After sweep 1: maxlinkdim=323 maxerr=2.22E-16 current_time=0.0 - 0.1im time=85.477
# timestep 324 of 500 complete
# After sweep 1: maxlinkdim=325 maxerr=2.21E-16 current_time=0.0 - 0.1im time=86.791
# timestep 325 of 500 complete
# After sweep 1: maxlinkdim=326 maxerr=2.22E-16 current_time=0.0 - 0.1im time=87.646
# timestep 326 of 500 complete
# After sweep 1: maxlinkdim=327 maxerr=2.22E-16 current_time=0.0 - 0.1im time=88.75
# timestep 327 of 500 complete
# After sweep 1: maxlinkdim=329 maxerr=2.22E-16 current_time=0.0 - 0.1im time=91.757
# timestep 328 of 500 complete
# After sweep 1: maxlinkdim=331 maxerr=2.22E-16 current_time=0.0 - 0.1im time=90.411
# timestep 329 of 500 complete
# After sweep 1: maxlinkdim=333 maxerr=2.22E-16 current_time=0.0 - 0.1im time=90.602
# timestep 330 of 500 complete
# After sweep 1: maxlinkdim=334 maxerr=2.22E-16 current_time=0.0 - 0.1im time=92.038
# timestep 331 of 500 complete
# After sweep 1: maxlinkdim=335 maxerr=2.22E-16 current_time=0.0 - 0.1im time=92.527
# timestep 332 of 500 complete
# After sweep 1: maxlinkdim=337 maxerr=2.21E-16 current_time=0.0 - 0.1im time=93.886
# timestep 333 of 500 complete
# After sweep 1: maxlinkdim=338 maxerr=2.22E-16 current_time=0.0 - 0.1im time=94.228
# timestep 334 of 500 complete
# After sweep 1: maxlinkdim=339 maxerr=2.22E-16 current_time=0.0 - 0.1im time=96.16
# timestep 335 of 500 complete
# After sweep 1: maxlinkdim=341 maxerr=2.21E-16 current_time=0.0 - 0.1im time=97.054
# timestep 336 of 500 complete
# After sweep 1: maxlinkdim=342 maxerr=2.22E-16 current_time=0.0 - 0.1im time=97.89
# timestep 337 of 500 complete
# After sweep 1: maxlinkdim=344 maxerr=2.22E-16 current_time=0.0 - 0.1im time=98.994
# timestep 338 of 500 complete
# After sweep 1: maxlinkdim=345 maxerr=2.21E-16 current_time=0.0 - 0.1im time=100.963
# timestep 339 of 500 complete
# After sweep 1: maxlinkdim=347 maxerr=2.22E-16 current_time=0.0 - 0.1im time=101.388
# timestep 340 of 500 complete
# After sweep 1: maxlinkdim=348 maxerr=2.22E-16 current_time=0.0 - 0.1im time=102.222
# timestep 341 of 500 complete
# After sweep 1: maxlinkdim=349 maxerr=2.22E-16 current_time=0.0 - 0.1im time=102.529
# timestep 342 of 500 complete
# After sweep 1: maxlinkdim=351 maxerr=2.22E-16 current_time=0.0 - 0.1im time=104.43
# timestep 343 of 500 complete
# After sweep 1: maxlinkdim=352 maxerr=2.22E-16 current_time=0.0 - 0.1im time=105.022
# timestep 344 of 500 complete
# After sweep 1: maxlinkdim=353 maxerr=2.22E-16 current_time=0.0 - 0.1im time=106.839
# timestep 345 of 500 complete
# After sweep 1: maxlinkdim=355 maxerr=2.22E-16 current_time=0.0 - 0.1im time=108.036
# timestep 346 of 500 complete
# After sweep 1: maxlinkdim=356 maxerr=2.22E-16 current_time=0.0 - 0.1im time=108.443
# timestep 347 of 500 complete
# After sweep 1: maxlinkdim=358 maxerr=2.22E-16 current_time=0.0 - 0.1im time=109.601
# timestep 348 of 500 complete
# After sweep 1: maxlinkdim=359 maxerr=2.22E-16 current_time=0.0 - 0.1im time=112.334
# timestep 349 of 500 complete
# After sweep 1: maxlinkdim=361 maxerr=2.22E-16 current_time=0.0 - 0.1im time=112.787
# timestep 350 of 500 complete
# After sweep 1: maxlinkdim=363 maxerr=2.22E-16 current_time=0.0 - 0.1im time=114.053
# timestep 351 of 500 complete
# After sweep 1: maxlinkdim=365 maxerr=2.22E-16 current_time=0.0 - 0.1im time=115.807
# timestep 352 of 500 complete
# After sweep 1: maxlinkdim=367 maxerr=2.22E-16 current_time=0.0 - 0.1im time=116.161
# timestep 353 of 500 complete
# After sweep 1: maxlinkdim=368 maxerr=2.22E-16 current_time=0.0 - 0.1im time=117.797
# timestep 354 of 500 complete
# After sweep 1: maxlinkdim=370 maxerr=2.22E-16 current_time=0.0 - 0.1im time=119.449
# timestep 355 of 500 complete
# After sweep 1: maxlinkdim=372 maxerr=2.22E-16 current_time=0.0 - 0.1im time=121.291
# timestep 356 of 500 complete
# After sweep 1: maxlinkdim=373 maxerr=2.22E-16 current_time=0.0 - 0.1im time=121.731
# timestep 357 of 500 complete
# After sweep 1: maxlinkdim=375 maxerr=2.22E-16 current_time=0.0 - 0.1im time=122.288
# timestep 358 of 500 complete
# After sweep 1: maxlinkdim=377 maxerr=2.22E-16 current_time=0.0 - 0.1im time=123.156
# timestep 359 of 500 complete
# After sweep 1: maxlinkdim=378 maxerr=2.22E-16 current_time=0.0 - 0.1im time=124.755
# timestep 360 of 500 complete
# After sweep 1: maxlinkdim=380 maxerr=2.22E-16 current_time=0.0 - 0.1im time=125.667
# timestep 361 of 500 complete
# After sweep 1: maxlinkdim=382 maxerr=2.22E-16 current_time=0.0 - 0.1im time=130.143
# timestep 362 of 500 complete
# After sweep 1: maxlinkdim=383 maxerr=2.22E-16 current_time=0.0 - 0.1im time=130.875
# timestep 363 of 500 complete
# After sweep 1: maxlinkdim=384 maxerr=2.21E-16 current_time=0.0 - 0.1im time=132.19
# timestep 364 of 500 complete
# After sweep 1: maxlinkdim=386 maxerr=2.22E-16 current_time=0.0 - 0.1im time=134.242
# timestep 365 of 500 complete
# After sweep 1: maxlinkdim=388 maxerr=2.22E-16 current_time=0.0 - 0.1im time=135.798
# timestep 366 of 500 complete
# After sweep 1: maxlinkdim=389 maxerr=2.22E-16 current_time=0.0 - 0.1im time=136.833
# timestep 367 of 500 complete
# After sweep 1: maxlinkdim=391 maxerr=2.22E-16 current_time=0.0 - 0.1im time=139.047
# timestep 368 of 500 complete
# After sweep 1: maxlinkdim=393 maxerr=2.22E-16 current_time=0.0 - 0.1im time=140.927
# timestep 369 of 500 complete
# After sweep 1: maxlinkdim=395 maxerr=2.22E-16 current_time=0.0 - 0.1im time=142.095
# timestep 370 of 500 complete
# After sweep 1: maxlinkdim=396 maxerr=2.22E-16 current_time=0.0 - 0.1im time=143.994
# timestep 371 of 500 complete
# After sweep 1: maxlinkdim=398 maxerr=2.22E-16 current_time=0.0 - 0.1im time=145.744
# timestep 372 of 500 complete
# After sweep 1: maxlinkdim=400 maxerr=2.22E-16 current_time=0.0 - 0.1im time=147.763
# timestep 373 of 500 complete
# After sweep 1: maxlinkdim=402 maxerr=2.21E-16 current_time=0.0 - 0.1im time=149.474
# timestep 374 of 500 complete
# After sweep 1: maxlinkdim=403 maxerr=2.22E-16 current_time=0.0 - 0.1im time=151.869
# timestep 375 of 500 complete
# After sweep 1: maxlinkdim=405 maxerr=2.22E-16 current_time=0.0 - 0.1im time=153.036
# timestep 376 of 500 complete
# After sweep 1: maxlinkdim=406 maxerr=2.22E-16 current_time=0.0 - 0.1im time=152.738
# timestep 377 of 500 complete
# After sweep 1: maxlinkdim=409 maxerr=2.22E-16 current_time=0.0 - 0.1im time=157.073
# timestep 378 of 500 complete
# After sweep 1: maxlinkdim=410 maxerr=2.22E-16 current_time=0.0 - 0.1im time=160.034
# timestep 379 of 500 complete
# After sweep 1: maxlinkdim=412 maxerr=2.22E-16 current_time=0.0 - 0.1im time=164.377
# timestep 380 of 500 complete
# After sweep 1: maxlinkdim=414 maxerr=2.22E-16 current_time=0.0 - 0.1im time=177.544
# timestep 381 of 500 complete
# After sweep 1: maxlinkdim=416 maxerr=2.22E-16 current_time=0.0 - 0.1im time=183.519
# timestep 382 of 500 complete
# After sweep 1: maxlinkdim=418 maxerr=2.22E-16 current_time=0.0 - 0.1im time=193.097
# timestep 383 of 500 complete
# After sweep 1: maxlinkdim=420 maxerr=2.22E-16 current_time=0.0 - 0.1im time=194.789
# timestep 384 of 500 complete
# After sweep 1: maxlinkdim=422 maxerr=2.22E-16 current_time=0.0 - 0.1im time=200.216
# timestep 385 of 500 complete
# After sweep 1: maxlinkdim=424 maxerr=2.22E-16 current_time=0.0 - 0.1im time=196.037
# timestep 386 of 500 complete
# After sweep 1: maxlinkdim=426 maxerr=2.22E-16 current_time=0.0 - 0.1im time=185.922
# timestep 387 of 500 complete
# After sweep 1: maxlinkdim=428 maxerr=2.22E-16 current_time=0.0 - 0.1im time=194.638
# timestep 388 of 500 complete
# After sweep 1: maxlinkdim=429 maxerr=2.22E-16 current_time=0.0 - 0.1im time=197.652
# timestep 389 of 500 complete
# After sweep 1: maxlinkdim=431 maxerr=2.22E-16 current_time=0.0 - 0.1im time=200.956
# timestep 390 of 500 complete
# After sweep 1: maxlinkdim=433 maxerr=2.22E-16 current_time=0.0 - 0.1im time=205.387
# timestep 391 of 500 complete
# After sweep 1: maxlinkdim=434 maxerr=2.22E-16 current_time=0.0 - 0.1im time=208.375
# timestep 392 of 500 complete
# After sweep 1: maxlinkdim=436 maxerr=2.22E-16 current_time=0.0 - 0.1im time=199.059
# timestep 393 of 500 complete
# After sweep 1: maxlinkdim=438 maxerr=2.22E-16 current_time=0.0 - 0.1im time=192.111
# timestep 394 of 500 complete
# After sweep 1: maxlinkdim=440 maxerr=2.22E-16 current_time=0.0 - 0.1im time=195.107
# timestep 395 of 500 complete
# After sweep 1: maxlinkdim=442 maxerr=2.22E-16 current_time=0.0 - 0.1im time=197.727
# timestep 396 of 500 complete
# After sweep 1: maxlinkdim=443 maxerr=2.22E-16 current_time=0.0 - 0.1im time=200.924
# timestep 397 of 500 complete
# After sweep 1: maxlinkdim=445 maxerr=2.22E-16 current_time=0.0 - 0.1im time=202.079
# timestep 398 of 500 complete
# After sweep 1: maxlinkdim=447 maxerr=2.22E-16 current_time=0.0 - 0.1im time=205.714
# timestep 399 of 500 complete
# After sweep 1: maxlinkdim=449 maxerr=2.22E-16 current_time=0.0 - 0.1im time=205.726
# timestep 400 of 500 complete
# After sweep 1: maxlinkdim=451 maxerr=2.22E-16 current_time=0.0 - 0.1im time=209.469
# timestep 401 of 500 complete
# After sweep 1: maxlinkdim=453 maxerr=2.22E-16 current_time=0.0 - 0.1im time=216.204
# timestep 402 of 500 complete
# After sweep 1: maxlinkdim=455 maxerr=2.22E-16 current_time=0.0 - 0.1im time=231.977
# timestep 403 of 500 complete
# After sweep 1: maxlinkdim=457 maxerr=2.22E-16 current_time=0.0 - 0.1im time=254.514
# timestep 404 of 500 complete
# After sweep 1: maxlinkdim=459 maxerr=2.22E-16 current_time=0.0 - 0.1im time=253.616
# timestep 405 of 500 complete
# After sweep 1: maxlinkdim=460 maxerr=2.22E-16 current_time=0.0 - 0.1im time=249.397
# timestep 406 of 500 complete
# After sweep 1: maxlinkdim=462 maxerr=2.22E-16 current_time=0.0 - 0.1im time=253.33
# timestep 407 of 500 complete
# After sweep 1: maxlinkdim=463 maxerr=2.22E-16 current_time=0.0 - 0.1im time=259.649
# timestep 408 of 500 complete
# After sweep 1: maxlinkdim=465 maxerr=2.22E-16 current_time=0.0 - 0.1im time=267.243
# timestep 409 of 500 complete
# After sweep 1: maxlinkdim=467 maxerr=2.22E-16 current_time=0.0 - 0.1im time=262.086
# timestep 410 of 500 complete
# After sweep 1: maxlinkdim=469 maxerr=2.22E-16 current_time=0.0 - 0.1im time=262.758
# timestep 411 of 500 complete
# After sweep 1: maxlinkdim=470 maxerr=2.22E-16 current_time=0.0 - 0.1im time=273.807
# timestep 412 of 500 complete
# After sweep 1: maxlinkdim=471 maxerr=2.22E-16 current_time=0.0 - 0.1im time=278.76
# timestep 413 of 500 complete
# After sweep 1: maxlinkdim=473 maxerr=2.22E-16 current_time=0.0 - 0.1im time=279.575
# timestep 414 of 500 complete
# After sweep 1: maxlinkdim=475 maxerr=2.22E-16 current_time=0.0 - 0.1im time=281.847
# timestep 415 of 500 complete
# After sweep 1: maxlinkdim=477 maxerr=2.22E-16 current_time=0.0 - 0.1im time=283.699
# timestep 416 of 500 complete
# After sweep 1: maxlinkdim=479 maxerr=2.22E-16 current_time=0.0 - 0.1im time=289.334
# timestep 417 of 500 complete
# After sweep 1: maxlinkdim=486 maxerr=2.22E-16 current_time=0.0 - 0.1im time=292.965
# timestep 418 of 500 complete
# After sweep 1: maxlinkdim=494 maxerr=2.22E-16 current_time=0.0 - 0.1im time=298.162
# timestep 419 of 500 complete
# After sweep 1: maxlinkdim=502 maxerr=2.22E-16 current_time=0.0 - 0.1im time=298.8
# timestep 420 of 500 complete
# After sweep 1: maxlinkdim=510 maxerr=2.22E-16 current_time=0.0 - 0.1im time=285.794
# timestep 421 of 500 complete
# After sweep 1: maxlinkdim=518 maxerr=2.22E-16 current_time=0.0 - 0.1im time=289.508
# timestep 422 of 500 complete
# After sweep 1: maxlinkdim=527 maxerr=2.22E-16 current_time=0.0 - 0.1im time=294.362
# timestep 423 of 500 complete
# After sweep 1: maxlinkdim=535 maxerr=2.22E-16 current_time=0.0 - 0.1im time=299.217
# timestep 424 of 500 complete
# After sweep 1: maxlinkdim=545 maxerr=2.22E-16 current_time=0.0 - 0.1im time=304.048
# timestep 425 of 500 complete
# After sweep 1: maxlinkdim=554 maxerr=2.22E-16 current_time=0.0 - 0.1im time=309.241
# timestep 426 of 500 complete
# After sweep 1: maxlinkdim=564 maxerr=2.22E-16 current_time=0.0 - 0.1im time=311.203
# timestep 427 of 500 complete
# After sweep 1: maxlinkdim=573 maxerr=2.22E-16 current_time=0.0 - 0.1im time=318.199
# timestep 428 of 500 complete
# After sweep 1: maxlinkdim=583 maxerr=2.22E-16 current_time=0.0 - 0.1im time=328.158
# timestep 429 of 500 complete
# After sweep 1: maxlinkdim=593 maxerr=2.22E-16 current_time=0.0 - 0.1im time=330.432
# timestep 430 of 500 complete
# After sweep 1: maxlinkdim=603 maxerr=2.22E-16 current_time=0.0 - 0.1im time=336.248
# timestep 431 of 500 complete
# After sweep 1: maxlinkdim=614 maxerr=2.22E-16 current_time=0.0 - 0.1im time=341.197
# timestep 432 of 500 complete
# After sweep 1: maxlinkdim=625 maxerr=2.22E-16 current_time=0.0 - 0.1im time=347.222
# timestep 433 of 500 complete
# After sweep 1: maxlinkdim=636 maxerr=2.22E-16 current_time=0.0 - 0.1im time=358.109
# timestep 434 of 500 complete
# After sweep 1: maxlinkdim=647 maxerr=2.22E-16 current_time=0.0 - 0.1im time=404.473
# timestep 435 of 500 complete
# After sweep 1: maxlinkdim=659 maxerr=2.22E-16 current_time=0.0 - 0.1im time=413.484
# timestep 436 of 500 complete
# After sweep 1: maxlinkdim=670 maxerr=2.22E-16 current_time=0.0 - 0.1im time=387.401
# timestep 437 of 500 complete
# After sweep 1: maxlinkdim=682 maxerr=2.22E-16 current_time=0.0 - 0.1im time=384.432
# timestep 438 of 500 complete
# After sweep 1: maxlinkdim=694 maxerr=2.22E-16 current_time=0.0 - 0.1im time=398.01
# timestep 439 of 500 complete
# After sweep 1: maxlinkdim=706 maxerr=2.22E-16 current_time=0.0 - 0.1im time=400.257
# timestep 440 of 500 complete
# After sweep 1: maxlinkdim=719 maxerr=2.22E-16 current_time=0.0 - 0.1im time=408.316
# timestep 441 of 500 complete
# After sweep 1: maxlinkdim=731 maxerr=2.22E-16 current_time=0.0 - 0.1im time=416.635
# timestep 442 of 500 complete
# After sweep 1: maxlinkdim=744 maxerr=2.22E-16 current_time=0.0 - 0.1im time=424.046
# timestep 443 of 500 complete
# After sweep 1: maxlinkdim=756 maxerr=2.22E-16 current_time=0.0 - 0.1im time=431.557
# timestep 444 of 500 complete
# After sweep 1: maxlinkdim=769 maxerr=2.22E-16 current_time=0.0 - 0.1im time=440.865
# timestep 445 of 500 complete
# After sweep 1: maxlinkdim=782 maxerr=2.22E-16 current_time=0.0 - 0.1im time=449.54
# timestep 446 of 500 complete
# After sweep 1: maxlinkdim=795 maxerr=2.22E-16 current_time=0.0 - 0.1im time=460.903
# timestep 447 of 500 complete
# After sweep 1: maxlinkdim=808 maxerr=2.22E-16 current_time=0.0 - 0.1im time=472.782
# timestep 448 of 500 complete
# After sweep 1: maxlinkdim=821 maxerr=2.22E-16 current_time=0.0 - 0.1im time=480.416
# timestep 449 of 500 complete
# After sweep 1: maxlinkdim=833 maxerr=2.22E-16 current_time=0.0 - 0.1im time=490.538

# %%
p1 = plot(collect(dt:dt:tmax), nSys1, label="Site 1 Occupation", xlabel="Time", ylabel="Occupation", title="\$1/K_B T=$beta, \\mu=$mu, g=$g, h_{sys} = $t_sys, V=$V_sys\$", lw=3)
plot!(p1, collect(dt:dt:tmax), nSys2, label="Site 2 Occupation", dpi=500, lw=3)

display(p1)
savefig("test.png")

# %%
function prepare_corrs(N, sys_occs; n_sites=sys_size)
    N_tot = 2N + n_sites
    C = zeros(ComplexF64, N_tot, N_tot)
    for n in 1:n_sites
        C[n,n] = sys_occs[n]
    end
    for n in 1:N
        C[n_sites + 2n - 1, n_sites + 2n - 1] = 1.0
        C[n_sites + 2n, n_sites + 2n] = 0.0
    end
    return C
end


function HamiltonianCorrs(N, H_sys, E1, t1, E2, t2; n_sites=sys_size)
    N_tot = 2N + n_sites
    H = zeros(ComplexF64, N_tot, N_tot)
    for n in 1:n_sites
        for m in 1:n_sites
            H[n,m] = H_sys[n,m]
        end
    end

    #nth system site coupling to bath
    H[n_sites,n_sites+1] = t1[1]
    H[n_sites+1,n_sites] = t1[1]
    H[n_sites,n_sites+2] = t2[1]
    H[n_sites+2,n_sites] = t2[1]

    for n in 1:N
        H[2n-1+n_sites, 2n-1+n_sites] = E1[n]
        H[2n+n_sites, 2n+n_sites] = E2[n]
    end
    for n in 2:N
        H[2n-1,2n+1] = t1[n]
        H[2n+1,2n-1] = t1[n]
        H[2n, 2n+2] = t2[n]
        H[2n+2, 2n] = t2[n]
    end
    return H
end

function evolve_corrs(C0, H, dt, tmax)
    Cs = Vector{Array{ComplexF64}}(undef, 0)
    times = collect(0:dt:tmax)
    C0 = Matrix(C0)
    H = Matrix(H)

    for t in times
        U = exp(-im*t*H)
        C = U * C0 * U'
        push!(Cs, C)
    end
    return Cs
end

# %%
#system params
sys_occs = [1.0, 0.0]
H_sys = [0.0 0.1; 0.1 0.0]
@assert issymmetric(H_sys) == true

J = spectral_func("elliptical", D, g)
J1, J2 = thermofield_transform(J, beta, mu)

E1, t1 = chain_map(J1, N, D)
E2, t2 = chain_map(J2, N, D)

H = HamiltonianCorrs(N, H_sys, E1, t1, E2, t2)
C0 = prepare_corrs(N,sys_occs)
Cs = evolve_corrs(C0, H, dt, tmax)

# %%
occ1 = zeros(length(Cs))
occ2 = zeros(length(Cs))
for (t,C) in enumerate(Cs)
    occ1[t] = real(C[1,1])
    occ2[t] = real(C[2,2])
end

p = plot(dt:dt:tmax, occ1, label="Site 1 Exact", xlabel="Time", ylabel="Mean occupation", title="\$1/K_B T=$beta, \\mu=$mu, g=$g, h_{sys} = $t_sys, V=$V_sys\$", lw=3)
plot!(p, dt:dt:tmax, occ2, label="Site 2 Exact", dpi=500, lw=3)
plot!(p,0:dt:tmax, nSys1, label="MPS", linestyle=:dot, lw=3, c=:black)
plot!(p, 0:dt:tmax, nSys2, label="", linestyle=:dot, lw=3, c=:black)

display(p)
